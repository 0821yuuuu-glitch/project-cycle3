# %%
import pandas as pd
import warnings

# 忽略所有警告訊息
warnings.filterwarnings('ignore')

# 設定顯示選項，確保能看到所有欄位（避免出現 ...）
pd.set_option('display.max_columns', None)

# 1. 讀取資料
# 請確保路徑 '../cycle-3/Data/raw/YRBS_2007.csv' 是正確的
try:
    df = pd.read_csv('../cycle-3/Data/raw/YRBS_2007.csv')

    # 2. 列出所有欄位名稱與型態
    print(f"專案總欄位數：{df.shape[1]}")
    print("-" * 30)
    print("【所有欄位及其資料型態清單】")
    print(df.dtypes)

except FileNotFoundError:
    print("錯誤：找不到 CSV 檔案，請檢查路徑是否正確。")
# Out:
# 專案總欄位數：103
# ------------------------------
# 【所有欄位及其資料型態清單】
# RaceEth                   float64
# HowOldAreYou              float64
# WhatIsYourSex             float64
# InWhatGradeAreYou         float64
# AreYouHispanicOrLatino    float64
#                            ...
# HealthInGeneral           float64
# BMIPCT                    float64
# weight                    float64
# stratum                     int64
# psu                         int64
# Length: 103, dtype: object

# %%
# 計算全表缺失值
full_missing = df.isnull().sum()
full_missing_pct = (full_missing / len(df)) * 100

# 建立完整缺失值報告，並按缺失比例由高到低排序
missing_report = pd.DataFrame({
    '缺失筆數': full_missing,
    '缺失比例 (%)': full_missing_pct
}).sort_values(by='缺失比例 (%)', ascending=False)

print("【全表缺失值排序報告 (前 20 名)】")
print(missing_report.head(20))
# Out:
# 【全表缺失值排序報告 (前 20 名)】
#                           缺失筆數   缺失比例 (%)
# WhatIsYourRace            2147  15.290934
# UsedMotorcycleHelmet      2072  14.756784
# SunProtection             2013  14.336586
# HIVTesting                1921  13.681362
# Sleep                     1887  13.439214
# SunscreenUse              1882  13.403604
# InjuredWhileExercising    1863  13.268286
# HealthInGeneral           1848  13.161456
# MinutesInPEPlayingSports  1846  13.147212
# EverUsedLSD               1729  12.313938
# InjuriousSuicide          1715  12.214230
# AttemptedSuicide          1557  11.088954
# NoerobicExercise          1548  11.024856
# AerobicExercise           1530  10.896660
# HowObtainedCigarettes     1430  10.184460
# CurrentAlcoholUse         1372   9.771384
# SourceOfAlcohol           1267   9.023574
# EverAlcoholUse            1233   8.781426
# BirthControlPillUse       1186   8.446692
# CondomUse                 1135   8.083470

# %%
# 取得所有數值型欄位的統計摘要
full_desc = df.describe()

print("【全表數值欄位統計摘要】")
print(full_desc)

# 檢查是否有任何欄位是完全空的
empty_cols = df.columns[df.isnull().all()].tolist()
print(f"\n完全空白的欄位：{empty_cols if empty_cols else '無'}")
# Out:
# 【全表數值欄位統計摘要】
#             RaceEth  HowOldAreYou  WhatIsYourSex  InWhatGradeAreYou  \
# count  13793.000000  13980.000000   14028.000000       13972.000000
# mean       4.888059      5.131617       1.498432           2.509090
# std        1.551166      1.229040       0.500015           1.121361
# min        1.000000      1.000000       1.000000           1.000000
# 25%        3.000000      4.000000       1.000000           2.000000
# 50%        5.000000      5.000000       1.000000           3.000000
# 75%        6.000000      6.000000       2.000000           4.000000
# max        8.000000      7.000000       2.000000           5.000000
#
#        AreYouHispanicOrLatino  HowTallAreYouWithoutShoesInMeters  \
# count            13859.000000                       13062.000000
# mean                 1.719821                           1.694038
# std                  0.449103                           0.101466
# min                  1.000000                           1.270000
# 25%                  1.000000                           1.630000
# 50%                  2.000000                           1.680000
# 75%                  2.000000                           1.780000
# max                  2.000000                           2.110000
#
#        HowMuchDoYouWeighWithoutShoesInKG  BicyleHelmetUse   SeatBeltUse  \
# count                       13062.000000     13405.000000  13892.000000
# mean                           68.550172         1.947184      4.057299
# std                            16.990868         1.113005      1.115089
# min                            34.470000         1.000000      1.000000
# 25%                            56.700000         1.000000      3.000000
# 50%                            65.320000         2.000000      4.000000
# 75%                            77.110000         2.000000      5.000000
# max                           180.990000         6.000000      5.000000
#
#        RidingWithADrinkingDriver  DrinkingAndDriving  WeaponCarrying  \
# count               13416.000000        13634.000000    13615.000000
# mean                    1.649225            1.214611        1.508263
# std                     1.132821            0.703026        1.196219
# min                     1.000000            1.000000        1.000000
# 25%                     1.000000            1.000000        1.000000
# 50%                     1.000000            1.000000        1.000000
# 75%                     2.000000            1.000000        1.000000
# max                     5.000000            5.000000        5.000000
#
#        GunCarryingPast12Mos  WeaponCarryingAtSchool  SafetyConcernsAtSchool  \
# count          13356.000000            13740.000000            13894.000000
# mean               1.139413                1.161790                1.136462
# std                0.632125                0.715998                0.570469
# min                1.000000                1.000000                1.000000
# 25%                1.000000                1.000000                1.000000
# 50%                1.000000                1.000000                1.000000
# 75%                1.000000                1.000000                1.000000
# max                5.000000                5.000000                5.000000
#
#        WereThreatenedOrInjuredWithAWeaponOnSchoolProperty  \
# count                                       13894.000000
# mean                                            1.214265
# std                                             0.930119
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             8.000000
#
#        StolenOrDamagedYourProperty  PhysicalFighting  InjuredIFight  \
# count                 13754.000000      13720.000000   13685.000000
# mean                      1.526029          1.805321       1.068031
# std                       1.142987          1.467012       0.371609
# min                       1.000000          1.000000       1.000000
# 25%                       1.000000          1.000000       1.000000
# 50%                       1.000000          1.000000       1.000000
# 75%                       2.000000          2.000000       1.000000
# max                       8.000000          8.000000       5.000000
#
#        PhysicalFightingAtSchool  BoyfriendGirlfriendPhysicallyHurt  \
# count              13751.000000                       13835.000000
# mean                   1.221875                           1.890929
# std                    0.763059                           0.311740
# min                    1.000000                           1.000000
# 25%                    1.000000                           2.000000
# 50%                    1.000000                           2.000000
# 75%                    1.000000                           2.000000
# max                    8.000000                           2.000000
#
#        ForcedSexualIntercourse  SadOrHopeless  ConsideredSuicide  \
# count             13818.000000   13845.000000       13859.000000
# mean                  1.914966       1.700036           1.849051
# std                   0.278942       0.458258           0.358012
# min                   1.000000       1.000000           1.000000
# 25%                   2.000000       1.000000           2.000000
# 50%                   2.000000       2.000000           2.000000
# 75%                   2.000000       2.000000           2.000000
# max                   2.000000       2.000000           2.000000
#
#        MadeASuicidePlan  AttemptedSuicide  InjuriousSuicide  EverCigaretteUse  \
# count      13802.000000      12484.000000      12326.000000      13601.000000
# mean           1.880597          1.139058          1.134188          1.473274
# std            0.324274          0.545208          0.476299          0.499304
# min            1.000000          1.000000          1.000000          1.000000
# 25%            2.000000          1.000000          1.000000          1.000000
# 50%            2.000000          1.000000          1.000000          1.000000
# 75%            2.000000          1.000000          1.000000          2.000000
# max            2.000000          5.000000          3.000000          2.000000
#
#        InitiationSmokingWholeCigarette  CurrentCigaretteUse  \
# count                     13500.000000         13323.000000
# mean                          2.489037             1.653006
# std                           2.032104             1.597524
# min                           1.000000             1.000000
# 25%                           1.000000             1.000000
# 50%                           1.000000             1.000000
# 75%                           5.000000             1.000000
# max                           7.000000             7.000000
#
#        SmokedMoreThan10Cigarettes  HowObtainedCigarettes  \
# count                13211.000000           12611.000000
# mean                     1.522898               1.684482
# std                      1.202565               1.625470
# min                      1.000000               1.000000
# 25%                      1.000000               1.000000
# 50%                      1.000000               1.000000
# 75%                      1.000000               1.000000
# max                      7.000000               8.000000
#
#        SmokeOnSchoolProperty  EverSmokedDailyFor30Days  EverSmokingCessation  \
# count           13595.000000              13497.000000          13297.000000
# mean                1.139463                  1.890716              1.394525
# std                 0.736088                  0.312006              0.706166
# min                 1.000000                  1.000000              1.000000
# 25%                 1.000000                  2.000000              1.000000
# 50%                 1.000000                  2.000000              1.000000
# 75%                 1.000000                  2.000000              2.000000
# max                 7.000000                  2.000000              3.000000
#
#        CurrentSmokelessTobaccoUse  CurrentSmokelessTobaccoOnSchoolProperty  \
# count                13419.000000                             12930.000000
# mean                     1.215739                                 1.138747
# std                      0.969671                                 0.791179
# min                      1.000000                                 1.000000
# 25%                      1.000000                                 1.000000
# 50%                      1.000000                                 1.000000
# 75%                      1.000000                                 1.000000
# max                      7.000000                                 7.000000
#
#        CurrentCigarUse  EverAlcoholUse  InitiationOfAlcoholUse  \
# count     13478.000000    12808.000000            13755.000000
# mean          1.313251        3.328701                3.707961
# std           0.996747        1.994295                2.044614
# min           1.000000        1.000000                1.000000
# 25%           1.000000        2.000000                1.000000
# 50%           1.000000        3.000000                4.000000
# 75%           1.000000        5.000000                5.000000
# max           7.000000        7.000000                7.000000
#
#        CurrentAlcoholUse  CurrentBingeDrinking5OrMore  SourceOfAlcohol  \
# count       12669.000000                 13588.000000     12774.000000
# mean            1.904176                     1.615470         3.238453
# std             1.294546                     1.247765         2.637225
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     1.000000         1.000000
# 50%             1.000000                     1.000000         1.000000
# 75%             2.000000                     2.000000         6.000000
# max             7.000000                     7.000000         8.000000
#
#        DrinkAlcoholOnSchoolProperty  EverMarijuaUse  InitiationOfMarijuaUse  \
# count                  13687.000000    13632.000000            13696.000000
# mean                       1.090597        2.319542                2.675307
# std                        0.506545        2.007032                2.147926
# min                        1.000000        1.000000                1.000000
# 25%                        1.000000        1.000000                1.000000
# 50%                        1.000000        1.000000                1.000000
# 75%                        1.000000        3.000000                5.000000
# max                        7.000000        7.000000                7.000000
#
#        CurrentMarijuaUse  MarijuaOnSchoolProperty  EverCocaineUse  \
# count       13664.000000             13718.000000    13792.000000
# mean            1.505782                 1.105482        1.183005
# std             1.202645                 0.560957        0.765533
# min             1.000000                 1.000000        1.000000
# 25%             1.000000                 1.000000        1.000000
# 50%             1.000000                 1.000000        1.000000
# 75%             1.000000                 1.000000        1.000000
# max             6.000000                 6.000000        6.000000
#
#        CocaineUsePast30Days  EverInhalantUse  EverHeroinUse  \
# count          13217.000000     13808.000000   13838.000000
# mean               1.084361         1.246451       1.065689
# std                0.519077         0.801169       0.492870
# min                1.000000         1.000000       1.000000
# 25%                1.000000         1.000000       1.000000
# 50%                1.000000         1.000000       1.000000
# 75%                1.000000         1.000000       1.000000
# max                6.000000         6.000000       6.000000
#
#        EverMethamphetamineUse  EverEcstasyUse  EverSteriodUse  \
# count            13823.000000    13788.000000    13844.000000
# mean                 1.107791        1.126632        1.091809
# std                  0.601413        0.610402        0.554891
# min                  1.000000        1.000000        1.000000
# 25%                  1.000000        1.000000        1.000000
# 50%                  1.000000        1.000000        1.000000
# 75%                  1.000000        1.000000        1.000000
# max                  6.000000        6.000000        6.000000
#
#        IllegalInjectedDrugUse  IllegalDrugsAtSchool  EverSexualIntercourse  \
# count            13842.000000          13830.000000           13106.000000
# mean                 1.034244              1.770137               1.475507
# std                  0.233365              0.420760               0.499419
# min                  1.000000              1.000000               1.000000
# 25%                  1.000000              2.000000               1.000000
# 50%                  1.000000              2.000000               1.000000
# 75%                  1.000000              2.000000               2.000000
# max                  3.000000              2.000000               2.000000
#
#        FirstSexualIntercourse  MultipleSexPartners  CurrentSexualActivity  \
# count            13086.000000         13061.000000           13076.000000
# mean                 3.257680             2.543067               2.149893
# std                  2.456143             2.008730               1.432542
# min                  1.000000             1.000000               1.000000
# 25%                  1.000000             1.000000               1.000000
# 50%                  2.000000             2.000000               2.000000
# 75%                  6.000000             4.000000               3.000000
# max                  8.000000             7.000000               8.000000
#
#        AlcoholDrugsAndSex     CondomUse  BirthControlPillUse  \
# count        13062.000000  12906.000000         12855.000000
# mean             1.943271      1.709747             2.573551
# std              0.943507      0.761771             1.817361
# min              1.000000      1.000000             1.000000
# 25%              1.000000      1.000000             1.000000
# 50%              2.000000      2.000000             2.000000
# 75%              3.000000      2.000000             4.000000
# max              3.000000      3.000000             8.000000
#
#        PerceptionOfWeight    WeightLoss  ExerciseToLoseWeight  \
# count        13794.000000  13791.000000          13719.000000
# mean             3.190155      2.090204              1.395874
# std              0.770017      1.155803              0.489055
# min              1.000000      1.000000              1.000000
# 25%              3.000000      1.000000              1.000000
# 50%              3.000000      2.000000              1.000000
# 75%              4.000000      3.000000              2.000000
# max              5.000000      4.000000              2.000000
#
#        ConsumeFewerCaloriesToLoseWeight  FastingToLoseWeight  \
# count                      13734.000000         13233.000000
# mean                           1.602811             1.879317
# std                            0.489334             0.325771
# min                            1.000000             1.000000
# 25%                            1.000000             2.000000
# 50%                            2.000000             2.000000
# 75%                            2.000000             2.000000
# max                            2.000000             2.000000
#
#        DietPillsToLoseWeight  LaxativesToLoseWeight  FruitJuiceDrinking  \
# count           13335.000000           13735.000000        13895.000000
# mean                1.940532               1.955806            2.993451
# std                 0.236507               0.205533            1.799757
# min                 1.000000               1.000000            1.000000
# 25%                 2.000000               2.000000            2.000000
# 50%                 2.000000               2.000000            2.000000
# 75%                 2.000000               2.000000            4.000000
# max                 2.000000               2.000000            7.000000
#
#         FruitEating  GreenSaladEating  PotatoEating  CarrotEating  \
# count  13893.000000      13446.000000  13449.000000  13424.000000
# mean       2.930828          2.048639      2.012640      1.677443
# std        1.627544          1.219837      1.126378      1.067258
# min        1.000000          1.000000      1.000000      1.000000
# 25%        2.000000          1.000000      1.000000      1.000000
# 50%        2.000000          2.000000      2.000000      1.000000
# 75%        4.000000          2.000000      2.000000      2.000000
# max        7.000000          7.000000      7.000000      7.000000
#
#        OtherVegetableEating  NoSodaDrinking  NoMilkDrinking  \
# count          13426.000000    13905.000000    13598.000000
# mean               2.593773        3.193312        3.157964
# std                1.384254        1.849882        1.804375
# min                1.000000        1.000000        1.000000
# 25%                2.000000        2.000000        2.000000
# 50%                2.000000        3.000000        3.000000
# 75%                3.000000        5.000000        4.000000
# max                7.000000        7.000000        7.000000
#
#        PhysicalActivity5OrMoreDays  TelevisionWatching   ComputerUse  \
# count                 13840.000000        13825.000000  13817.000000
# mean                      4.032298            4.037251      3.263009
# std                       2.565657            1.815766      1.854357
# min                       1.000000            1.000000      1.000000
# 25%                       1.000000            3.000000      2.000000
# 50%                       4.000000            4.000000      3.000000
# 75%                       6.000000            5.000000      4.000000
# max                       8.000000            7.000000      7.000000
#
#        PEAttendance  SportsTeamParticipation  TaughtAboutHIV        Asthma  \
# count  13653.000000             13496.000000    13508.000000  13761.000000
# mean       3.044972                 1.954727        1.169677      1.827701
# std        2.234010                 1.055599        0.475279      0.455943
# min        1.000000                 1.000000        1.000000      1.000000
# 25%        1.000000                 1.000000        1.000000      2.000000
# 50%        2.000000                 2.000000        1.000000      2.000000
# 75%        6.000000                 3.000000        1.000000      2.000000
# max        6.000000                 4.000000        3.000000      3.000000
#
#        StillHaveAsthma  UsedMotorcycleHelmet   EverUsedLSD  AerobicExercise  \
# count     13184.000000          11969.000000  12312.000000     12511.000000
# mean          1.681356              1.768819      1.142057         4.572376
# std           0.999369              1.603944      0.631179         2.508980
# min           1.000000              1.000000      1.000000         1.000000
# 25%           1.000000              1.000000      1.000000         2.000000
# 50%           1.000000              1.000000      1.000000         5.000000
# 75%           2.000000              1.000000      1.000000         7.000000
# max           4.000000              6.000000      6.000000         8.000000
#
#        NoerobicExercise  MinutesInPEPlayingSports  InjuredWhileExercising  \
# count      12493.000000              12195.000000            12178.000000
# mean           3.570640                  3.374498                2.379373
# std            2.494998                  2.548282                0.830621
# min            1.000000                  1.000000                1.000000
# 25%            1.000000                  1.000000                2.000000
# 50%            3.000000                  3.000000                3.000000
# 75%            5.000000                  5.000000                3.000000
# max            8.000000                  8.000000                3.000000
#
#          HIVTesting  SunscreenUse  SunProtection         Sleep  \
# count  12120.000000  12159.000000   12028.000000  12154.000000
# mean       1.921535      1.864792       2.478883      3.795458
# std        0.448741      1.050999       1.147029      1.347275
# min        1.000000      1.000000       1.000000      1.000000
# 25%        2.000000      1.000000       2.000000      3.000000
# 50%        2.000000      2.000000       2.000000      4.000000
# 75%        2.000000      2.000000       3.000000      5.000000
# max        3.000000      5.000000       5.000000      7.000000
#
#        HealthInGeneral        BMIPCT        weight       stratum  \
# count     12193.000000  1.306200e+04  14041.000000  14041.000000
# mean          2.580579  6.482068e+01      1.000001    158.207250
# std           0.990650  2.751676e+01      0.820895     51.082118
# min           1.000000  3.720000e-09      0.010600    101.000000
# 25%           2.000000  4.516627e+01      0.370300    104.000000
# 50%           3.000000  7.013853e+01      0.784500    201.000000
# 75%           3.000000  8.945097e+01      1.468900    211.000000
# max           5.000000  9.993921e+01      8.130100    214.000000
#
#                  psu
# count   14041.000000
# mean   256357.760986
# std    167176.573944
# min     11030.000000
# 25%     60990.000000
# 50%    250270.000000
# 75%    371270.000000
# max    551110.000000
#
# 完全空白的欄位：無

# %%
# 第一次執行請先安裝套件（安裝完後可將此行刪除或註解掉）
# !pip install matplotlib seaborn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 嘗試自動抓取系統中文字體，避免報錯
try:
    # Windows 常用字體
    plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei', 'SimHei', 'Arial Unicode MS'] 
    plt.rcParams['axes.unicode_minus'] = False
except:
    pass


# --- 1. 全表資料完整度圓餅圖 ---
total_cells = df.size
null_cells = df.isnull().sum().sum()
filled_cells = total_cells - null_cells

plt.figure(figsize=(8, 8))
plt.pie([filled_cells, null_cells], 
        labels=['有效數據 (Filled)', '缺失數據 (Missing)'], 
        autopct='%1.1f%%', 
        colors=['#66b3ff','#ff9999'], 
        startangle=90, 
        explode=(0.1, 0))
plt.title('圖表一：2007 YRBS 全表數據完整度總覽', fontsize=15)
fig1 = plt.gcf() # 將此圖存入變數 fig1

# --- 2. 欄位品質分類圓餅圖 ---
missing_pct = (df.isnull().sum() / len(df)) * 100
good_cols = len(missing_pct[missing_pct <= 5])
medium_cols = len(missing_pct[(missing_pct > 5) & (missing_pct <= 20)])
bad_cols = len(missing_pct[missing_pct > 20])

plt.figure(figsize=(8, 8))
plt.pie([good_cols, medium_cols, bad_cols], 
        labels=[f'優良欄位 (<5% 缺失)\n({good_cols}個)', 
                f'普通欄位 (5-20% 缺失)\n({medium_cols}個)', 
                f'嚴重缺失 (>20% 缺失)\n({bad_cols}個)'], 
        autopct='%1.1f%%', 
        colors=['#99ff99','#ffcc99','#ff6666'], 
        startangle=140)
plt.title('圖表二：各欄位資料品質分佈', fontsize=15)
fig2 = plt.gcf() # 將此圖存入變數 fig2

# --- 3. 缺失前 10 名長條圖 ---
# 修正重點：建立 missing_report 變數並排序
missing_report = pd.DataFrame({
    '欄位名稱': missing_pct.index,
    '缺失比例 (%)': missing_pct.values
}).sort_values(by='缺失比例 (%)', ascending=False)

plt.figure(figsize=(10, 6))
top_10_missing = missing_report.head(10)

# 修正重點：確保 sns 有定義，且 data 使用剛建立的 top_10_missing
sns.barplot(x='缺失比例 (%)', 
            y='欄位名稱', 
            data=top_10_missing, 
            palette='Reds_r', 
            hue='欄位名稱', 
            legend=False)

plt.title('圖表三：缺失比例最高的前 10 個欄位', fontsize=15)
plt.xlabel('缺失比例 (%)', fontsize=12)
plt.ylabel('欄位名稱', fontsize=12)
fig3 = plt.gcf() # 將此圖存入變數 fig3

# 此格不寫 plt.show()，確保下一格能讀取 fig1, fig2, fig3

# %%
# --- 存檔區塊：獨立執行儲存動作 ---
import os

# 1. 確保目錄存在
save_path = '../outputs/figures/'
os.makedirs(save_path, exist_ok=True)

# 2. 使用變數名執行儲存 (對應 Cell A 的 fig1, fig2, fig3)
fig1.savefig(os.path.join(save_path, '01_overall_integrity_pie.png'), dpi=300, bbox_inches='tight')
fig2.savefig(os.path.join(save_path, '01_column_quality_pie.png'), dpi=300, bbox_inches='tight')
fig3.savefig(os.path.join(save_path, '01_top_missing_bar.png'), dpi=300, bbox_inches='tight')

print(f"✅ 成功！3 張圖表已存入：{save_path}")
# Out:
# ✅ 成功！3 張圖表已存入：../outputs/figures/

# %%
# 存檔至 processed，保留所有原始欄位
output_path = '../cycle-3/Data/processed/YRBS_2007.csv'
df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f"✅ 全欄位檢查完成！完整資料已存至: {output_path}")
# Out:
# ✅ 全欄位檢查完成！完整資料已存至: ../cycle-3/Data/processed/YRBS_2007.csv
